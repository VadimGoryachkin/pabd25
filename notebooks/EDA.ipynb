# %%
import pandas as pd
import glob 
import matplotlib.pyplot as plt
import numpy as np
  
raw_data_path = '../data/raw'
file_list = glob.glob(raw_data_path + "/*.csv")

# %%
file_list
# Out:
# ['../data/raw\\1_2025-05-12_20-49.csv']

# %%
main_dataframe = pd.read_csv(file_list[0])
for i in range(1, len(file_list)): 
    data = pd.read_csv(file_list[i]) 
    df = pd.DataFrame(data) 
    main_dataframe = pd.concat([main_dataframe, df], axis=0)

# %%
main_dataframe
# Out:
#                   author        author_type  \
# 0            ID 12891703          homeowner
# 1    White and Broughton  real_estate_agent
# 2            OPN PARTNER  real_estate_agent
# 3    Татьяна Серебрякова            realtor
# 4         Юрий Артамонов            realtor
# ..                   ...                ...
# 417          ID 75966465          homeowner
# 418      Максим Гаврилов            realtor
# 419        Мария Иванова            realtor
# 420                  UBS  real_estate_agent
# 421           EstateLiga  real_estate_agent
#
#                                           url location deal_type  \
# 0    https://www.cian.ru/sale/flat/315747133/   Москва      sale
# 1    https://www.cian.ru/sale/flat/313640113/   Москва      sale
# 2    https://www.cian.ru/sale/flat/310107816/   Москва      sale
# 3    https://www.cian.ru/sale/flat/314672030/   Москва      sale
# 4    https://www.cian.ru/sale/flat/316989525/   Москва      sale
# ..                                        ...      ...       ...
# 417  https://www.cian.ru/sale/flat/314230831/   Москва      sale
# 418  https://www.cian.ru/sale/flat/312811317/   Москва      sale
# 419  https://www.cian.ru/sale/flat/314645665/   Москва      sale
# 420  https://www.cian.ru/sale/flat/314784162/   Москва      sale
# 421  https://www.cian.ru/sale/flat/312897713/   Москва      sale
#
#     accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 0                 flat     10            18            1          32.0
# 1                 flat      6            41            1          40.1
# 2                 flat      6            12            1          40.0
# 3                 flat     14            16            1          40.0
# 4                 flat      5            12            1          35.1
# ..                 ...    ...           ...          ...           ...
# 417               flat     15            16            1          40.0
# 418               flat      5            25            1          44.6
# 419               flat     18            24            1          38.5
# 420               flat      1            12            1          33.0
# 421               flat      3            25            1          30.0
#
#      price_per_month  commissions     price            district  \
# 0                 -1            0  13590000        Останкинский
# 1                 -1            0  35500000         Хорошевский
# 2                 -1            0   8490000                 NaN
# 3                 -1            0  12700000             Марьино
# 4                 -1            0  15950000         Даниловский
# ..               ...          ...       ...                 ...
# 417               -1            0  12900000            Строгино
# 418               -1            0  14500000             Марьино
# 419               -1            0  27800000   Хорошево-Мневники
# 420               -1            0   9100000  Северное Измайлово
# 421               -1            0  16000000      Филевский парк
#
#                        street house_number       underground  \
# 0             Березовая аллея         19к1  Ботанический сад
# 1      Ленинградский проспект         37/5          Аэропорт
# 2                 Харлампиева         52к1       Филатов Луг
# 3             Новомарьинская          16К1     Братиславская
# 4                     Сайкина            2     Автозаводская
# ..                        ...          ...               ...
# 417                  Кулакова           10          Строгино
# 418                 Донецкая          30к1         Курьяново
# 419  Шелепихинская набережная         40к3          Шелепиха
# 420         Сиреневый бульвар        37/40        Щёлковская
# 421          Береговой проезд         5Ак4              Фили
#
#                     residential_complex
# 0    Апарт-комплекс Легендарный квартал
# 1                            Прайм Парк
# 2                    Спортивный квартал
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 417                                 NaN
# 418                            Домашний
# 419                         Sydney City
# 420                                 NaN
# 421                           Фили Град
#
# [422 rows x 18 columns]

# %%
main_dataframe['url_id'] = main_dataframe['url'].map(lambda x: x.split('/')[-2])
new_dataframe = main_dataframe[['url_id', 'total_meters', 'price']].set_index('url_id')

# %%
new_dataframe['price'].hist()
# Out:
# <Axes: >

# %%
new_df = new_dataframe[new_dataframe['price'] < 100_000_000]
new_df = new_df[new_df['total_meters'] < 100]

# %%
x = new_df['total_meters']
y = new_df['price']

plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
new_df.to_csv('../data/processed/train.csv', index=False)
